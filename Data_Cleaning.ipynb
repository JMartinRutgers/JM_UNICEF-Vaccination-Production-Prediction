# %%
import pandas as pd
import numpy as np

# %%
allVacs = pd.read_csv('Resources/wuenic2018rev_data_2019-09-18.csv', index_col=0)
allVacs.head()
# Out:
#                Subgroup         Name  Year Vaccine  Coverage Vaccinated  \
# Group
# UNICEF Regions     ROSA  Afghanistan  2018     BCG        78    941,000
# UNICEF Regions     ROSA  Afghanistan  2018    DTP1        73    836,000
# UNICEF Regions     ROSA  Afghanistan  2018    DTP3        66    756,000
# UNICEF Regions     ROSA  Afghanistan  2018   Hepb3        66    756,000
# UNICEF Regions     ROSA  Afghanistan  2018   Hepbb        18    217,000
#
#                    Target                                             Source
# Group
# UNICEF Regions  1,207,000  WHO/UNICEF estimates of national immunization ...
# UNICEF Regions  1,146,000  WHO/UNICEF estimates of national immunization ...
# UNICEF Regions  1,146,000  WHO/UNICEF estimates of national immunization ...
# UNICEF Regions  1,146,000  WHO/UNICEF estimates of national immunization ...
# UNICEF Regions  1,207,000  WHO/UNICEF estimates of national immunization ...

# %%
Afghanistan=allVacs[allVacs["Name"]=="Afghanistan"]
Albania=allVacs[allVacs["Name"]=="Albania"]
Algeria=allVacs[allVacs["Name"]=="Algeria"]
Andorra=allVacs[allVacs["Name"]=="Andorra"]
Angola=allVacs[allVacs["Name"]=="Angola"]
Antigua_Barbuda=allVacs[allVacs["Name"]=="Antigua and Barbuda"]
Argentina=allVacs[allVacs["Name"]=="Argentina"]
Armenia=allVacs[allVacs["Name"]=="Armenia"]
Australia=allVacs[allVacs["Name"]=="Australia"]
Austria=allVacs[allVacs["Name"]=="Austria"]
Austria=allVacs[allVacs["Name"]=="Austria"]
Azerbaijan=allVacs[allVacs["Name"]=="Azerbaijan"]
Bahamas=allVacs[allVacs["Name"]=="Bahamas"]
Bahrain=allVacs[allVacs["Name"]=="Bahrain"]
Bangladesh=allVacs[allVacs["Name"]=="Bangladesh"]
Barbados=allVacs[allVacs["Name"]=="Barbados"]
Belarus=allVacs[allVacs["Name"]=="Belarus"]
Belgium=allVacs[allVacs["Name"]=="Belgium"]
Belize=allVacs[allVacs["Name"]=="Belize"]
Benin=allVacs[allVacs["Name"]=="Benin"]
Bhutan=allVacs[allVacs["Name"]=="Bhutan"]
Bolivia=allVacs[allVacs["Name"]=="Bolivia (Plurinational State of)"]
Bosnia_Herzegovina=allVacs[allVacs["Name"]=="Bosnia and Herzegovina"]
Botswana=allVacs[allVacs["Name"]=="Botswana"]
Brazil=allVacs[allVacs["Name"]=="Brazil"]
Brunei_Darussalam=allVacs[allVacs["Name"]=="Brunei Darussalam"]
Bulgaria=allVacs[allVacs["Name"]=="Bulgaria"]
Burkina_Faso=allVacs[allVacs["Name"]=="Burkina Faso"]
Burundi=allVacs[allVacs["Name"]=="Burundi"]
Cabo_Verde=allVacs[allVacs["Name"]=="Cabo Verde"]
Cambodia=allVacs[allVacs["Name"]=="Cambodia"]
Cameroon=allVacs[allVacs["Name"]=="Cameroon"]
Canada=allVacs[allVacs["Name"]=="Canada"]
Central_African_Republic=allVacs[allVacs["Name"]=="Central African Republic"]
Chad=allVacs[allVacs["Name"]=="Chad"]
Chile=allVacs[allVacs["Name"]=="Chile"]
China=allVacs[allVacs["Name"]=="China"]
Colombia=allVacs[allVacs["Name"]=="Colombia"]
Comoros=allVacs[allVacs["Name"]=="Comoros"]
Congo=allVacs[allVacs["Name"]=="Congo"]
Cook_Islands=allVacs[allVacs["Name"]=="Cook Islands"]
Costa_Rica=allVacs[allVacs["Name"]=="Costa Rica"]
Cote_dIvoire=allVacs[allVacs["Name"]=="Cote d'Ivoire"]
Croatia=allVacs[allVacs["Name"]=="Croatia"]
Cuba=allVacs[allVacs["Name"]=="Cuba"]
Cyprus=allVacs[allVacs["Name"]=="Cyprus"]
Czechia=allVacs[allVacs["Name"]=="Czechia"]
North_Korea=allVacs[allVacs["Name"]=="Democratic People's Republic of Korea"]
DPCongo=allVacs[allVacs["Name"]=="Democratic Republic of the Congo"]
Denmark=allVacs[allVacs["Name"]=="Denmark"]
Djibouti=allVacs[allVacs["Name"]=="Djibouti"]
Dominica=allVacs[allVacs["Name"]=="Dominica"]
Dominican_Republic=allVacs[allVacs["Name"]=="Dominican Republic"]
Ecuador=allVacs[allVacs["Name"]=="Ecuador"]
Egypt=allVacs[allVacs["Name"]=="Egypt"]
El_Salvador=allVacs[allVacs["Name"]=="El Salvador"]
Equatorial_Guinea=allVacs[allVacs["Name"]=="Equatorial Guinea"]
Eritrea=allVacs[allVacs["Name"]=="Eritrea"]
Estonia=allVacs[allVacs["Name"]=="Estonia"]
Eswatini=allVacs[allVacs["Name"]=="Eswatini"]
Ethiopia=allVacs[allVacs["Name"]=="Ethiopia"]
Fiji=allVacs[allVacs["Name"]=="Fiji"]
Finland=allVacs[allVacs["Name"]=="Finland"]
France=allVacs[allVacs["Name"]=="France"]
Gabon=allVacs[allVacs["Name"]=="Gabon"]
Gambia=allVacs[allVacs["Name"]=="Gambia"]
Georgia=allVacs[allVacs["Name"]=="Georgia"]
Germany=allVacs[allVacs["Name"]=="Germany"]
Ghana=allVacs[allVacs["Name"]=="Ghana"]
Greece=allVacs[allVacs["Name"]=="Greece"]
Grenada=allVacs[allVacs["Name"]=="Grenada"]
Guatemala=allVacs[allVacs["Name"]=="Guatemala"]
Guinea=allVacs[allVacs["Name"]=="Guinea"]
Guinea_Bissau=allVacs[allVacs["Name"]=="Guinea-Bissau"]
Guyana=allVacs[allVacs["Name"]=="Guyana"]
Haiti=allVacs[allVacs["Name"]=="Haiti"]
Honduras=allVacs[allVacs["Name"]=="Honduras"]
Hungary=allVacs[allVacs["Name"]=="Hungary"]
Iceland=allVacs[allVacs["Name"]=="Iceland"]
India=allVacs[allVacs["Name"]=="India"]
Indonesia=allVacs[allVacs["Name"]=="Indonesia"]
Iran=allVacs[allVacs["Name"]=="Iran (Islamic Republic of)"]
Iraq=allVacs[allVacs["Name"]=="Iraq"]
Ireland=allVacs[allVacs["Name"]=="Ireland"]
Israel=allVacs[allVacs["Name"]=="Israel"]
Italy=allVacs[allVacs["Name"]=="Italy"]
Jamaica=allVacs[allVacs["Name"]=="Jamaica"]
Japan=allVacs[allVacs["Name"]=="Japan"]
Jordan=allVacs[allVacs["Name"]=="Jordan"]
Kazakhstan=allVacs[allVacs["Name"]=="Kazakhstan"]
Kenya=allVacs[allVacs["Name"]=="Kenya"]
Kiribati=allVacs[allVacs["Name"]=="Kiribati"]
Kuwait=allVacs[allVacs["Name"]=="Kuwait"]
Kyrgyzstan=allVacs[allVacs["Name"]=="Kyrgyzstan"]
Lao_PeoplesDP=allVacs[allVacs["Name"]=="Lao People's Democratic Republic"]
Latvia=allVacs[allVacs["Name"]=="Latvia"]
Lebanon=allVacs[allVacs["Name"]=="Lebanon"]
Lesotho=allVacs[allVacs["Name"]=="Lesotho"]
Liberia=allVacs[allVacs["Name"]=="Liberia"]
Libya=allVacs[allVacs["Name"]=="Libya"]
Lithuania=allVacs[allVacs["Name"]=="Lithuania"]
Luxembourg=allVacs[allVacs["Name"]=="Luxembourg"]
Madagascar=allVacs[allVacs["Name"]=="Madagascar"]
Malawi=allVacs[allVacs["Name"]=="Malawi"]
Malaysia=allVacs[allVacs["Name"]=="Malaysia"]
Maldives=allVacs[allVacs["Name"]=="Maldives"]
Mali=allVacs[allVacs["Name"]=="Mali"]
Malta=allVacs[allVacs["Name"]=="Malta"]
Marshall_Islands=allVacs[allVacs["Name"]=="Marshall Islands"]
Mauritania=allVacs[allVacs["Name"]=="Mauritania"]
Mauritius=allVacs[allVacs["Name"]=="Mauritius"]
Mexico=allVacs[allVacs["Name"]=="Mexico"]
Micronesia=allVacs[allVacs["Name"]=="Micronesia (Federated States of)"]
Monaco=allVacs[allVacs["Name"]=="Monaco"]
Mongolia=allVacs[allVacs["Name"]=="Mongolia"]
Montenegro=allVacs[allVacs["Name"]=="Montenegro"]
Morocco=allVacs[allVacs["Name"]=="Morocco"]
Mozambique=allVacs[allVacs["Name"]=="Mozambique"]
Myanmar=allVacs[allVacs["Name"]=="Myanmar"]
Namibia=allVacs[allVacs["Name"]=="Namibia"]
Nauru=allVacs[allVacs["Name"]=="Nauru"]
Nepal=allVacs[allVacs["Name"]=="Nepal"]
Netherlands=allVacs[allVacs["Name"]=="Netherlands"]
New_Zealand=allVacs[allVacs["Name"]=="New Zealand"]
Nicaragua=allVacs[allVacs["Name"]=="Nicaragua"]
Niger=allVacs[allVacs["Name"]=="Niger"]
Nigeria=allVacs[allVacs["Name"]=="Nigeria"]
Niue=allVacs[allVacs["Name"]=="Niue"]
Norway=allVacs[allVacs["Name"]=="Norway"]
Oman=allVacs[allVacs["Name"]=="Oman"]
Pakistan=allVacs[allVacs["Name"]=="Pakistan"]
Palau=allVacs[allVacs["Name"]=="Palau"]
Panama=allVacs[allVacs["Name"]=="Panama"]
Papua_New_Guinea=allVacs[allVacs["Name"]=="Papua New Guinea"]
Paraguay=allVacs[allVacs["Name"]=="Paraguay"]
Peru=allVacs[allVacs["Name"]=="Peru"]
Philippines=allVacs[allVacs["Name"]=="Philippines"]
Poland=allVacs[allVacs["Name"]=="Poland"]
Portugal=allVacs[allVacs["Name"]=="Portugal"]
Qatar=allVacs[allVacs["Name"]=="Qatar"]
South_Korea=allVacs[allVacs["Name"]=="Republic of Korea"]
Moldova=allVacs[allVacs["Name"]=="Republic of Moldova"]
North_Macedonia=allVacs[allVacs["Name"]=="Republic of North Macedonia"]
Romania=allVacs[allVacs["Name"]=="Romania"]
Russia=allVacs[allVacs["Name"]=="Russian Federation"]
Rwanda=allVacs[allVacs["Name"]=="Rwanda"]
Saint_Kitts_Nevis=allVacs[allVacs["Name"]=="Saint Kitts and Nevis"]
Saint_Lucia=allVacs[allVacs["Name"]=="Saint Lucia"]
Saint_Vincent_Grenadines=allVacs[allVacs["Name"]=="Saint Vincent and the Grenadines"]
Samoa=allVacs[allVacs["Name"]=="Samoa"]
San_Marino=allVacs[allVacs["Name"]=="San Marino"]
Sao_Tome_Principe=allVacs[allVacs["Name"]=="Sao Tome and Principe"]
Saudi_Arabia=allVacs[allVacs["Name"]=="Saudi Arabia"]
Senegal=allVacs[allVacs["Name"]=="Senegal"]
Serbia=allVacs[allVacs["Name"]=="Serbia"]
Seychelles=allVacs[allVacs["Name"]=="Seychelles"]
Sierra_Leone=allVacs[allVacs["Name"]=="Sierra Leone"]
Singapore=allVacs[allVacs["Name"]=="Singapore"]
Slovakia=allVacs[allVacs["Name"]=="Slovakia"]
Slovenia=allVacs[allVacs["Name"]=="Slovenia"]
Solomon_Islands=allVacs[allVacs["Name"]=="Solomon Islands"]
Somalia=allVacs[allVacs["Name"]=="Somalia"]
South_Africa=allVacs[allVacs["Name"]=="South Africa"]
South_Sudan=allVacs[allVacs["Name"]=="South Sudan"]
Spain=allVacs[allVacs["Name"]=="Spain"]
Sri_Lanka=allVacs[allVacs["Name"]=="Sri Lanka"]
Palestine=allVacs[allVacs["Name"]=="State of Palestine"]
Sudan=allVacs[allVacs["Name"]=="Sudan"]
Suriname=allVacs[allVacs["Name"]=="Suriname"]
Sweden=allVacs[allVacs["Name"]=="Sweden"]
Switzerland=allVacs[allVacs["Name"]=="Switzerland"]
Syria=allVacs[allVacs["Name"]=="Syrian Arab Republic"]
Tajikistan=allVacs[allVacs["Name"]=="Tajikistan"]
Thailand=allVacs[allVacs["Name"]=="Thailand"]
Timor_Leste=allVacs[allVacs["Name"]=="Timor-Leste"]
Togo=allVacs[allVacs["Name"]=="Togo"]
Tonga=allVacs[allVacs["Name"]=="Tonga"]
Trinidad_Tobago=allVacs[allVacs["Name"]=="Trinidad and Tobago"]
Tunisia=allVacs[allVacs["Name"]=="Tunisia"]
Turkey=allVacs[allVacs["Name"]=="Turkey"]
Turkmenistan=allVacs[allVacs["Name"]=="Turkmenistan"]
Tuvalu=allVacs[allVacs["Name"]=="Tuvalu"]
Uganda=allVacs[allVacs["Name"]=="Uganda"]
Ukraine=allVacs[allVacs["Name"]=="Ukraine"]
United_Arab_Emirates=allVacs[allVacs["Name"]=="United Arab Emirates"]
United_Kingdom=allVacs[allVacs["Name"]=="United Kingdom"]
United_States=allVacs[allVacs["Name"]=="United States"]
Tanzania=allVacs[allVacs["Name"]=="United Republic of Tanzania"]
Uruguay=allVacs[allVacs["Name"]=="Uruguay"]
Uzbekistan=allVacs[allVacs["Name"]=="Uzbekistan"]
Vanuatu=allVacs[allVacs["Name"]=="Vanuatu"]
Venezuela=allVacs[allVacs["Name"]=="Venezuela (Bolivarian Republic of)"]
Viet_Nam=allVacs[allVacs["Name"]=="Viet Nam"]
Yemen=allVacs[allVacs["Name"]=="Yemen"]
Zambia=allVacs[allVacs["Name"]=="Zambia"]
Zimbabwe=allVacs[allVacs["Name"]=="Zimbabwe"]

# %%
Australia["Region"]="East Asia & Pacific"
Brunei_Darussalam["Region"]="East Asia & Pacific"
Cambodia["Region"]="East Asia & Pacific"
China["Region"]="East Asia & Pacific"
Cook_Islands["Region"]="East Asia & Pacific"
North_Korea["Region"]="East Asia & Pacific"
Fiji["Region"]="East Asia & Pacific"
Indonesia["Region"]="East Asia & Pacific"
Japan["Region"]="East Asia & Pacific"
Kiribati["Region"]="East Asia & Pacific"
Lao_PeoplesDP["Region"]="East Asia & Pacific"
Malaysia["Region"]="East Asia & Pacific"
Marshall_Islands["Region"]="East Asia & Pacific"
Micronesia["Region"]="East Asia & Pacific"
Mongolia["Region"]="East Asia & Pacific"
Myanmar["Region"]="East Asia & Pacific"
New_Zealand["Region"]="East Asia & Pacific"
Nauru["Region"]="East Asia & Pacific"
Niue["Region"]="East Asia & Pacific"
Papua_New_Guinea["Region"]="East Asia & Pacific"
Palau["Region"]="East Asia & Pacific"
Philippines["Region"]="East Asia & Pacific"
South_Korea["Region"]="East Asia & Pacific"
Samoa["Region"]="East Asia & Pacific"
Singapore["Region"]="East Asia & Pacific"
Solomon_Islands["Region"]="East Asia & Pacific"
Thailand["Region"]="East Asia & Pacific"
Timor_Leste["Region"]="East Asia & Pacific"
Tonga["Region"]="East Asia & Pacific"
Tuvalu["Region"]="East Asia & Pacific"
Vanuatu["Region"]="East Asia & Pacific"
Viet_Nam["Region"]="East Asia & Pacific"
Albania["Region"]="Eastern Europe & Central Asia"
Armenia["Region"]="Eastern Europe & Central Asia"
Azerbaijan["Region"]="Eastern Europe & Central Asia"
Belarus["Region"]="Eastern Europe & Central Asia"
Bosnia_Herzegovina["Region"]="Eastern Europe & Central Asia"
Bulgaria["Region"]="Eastern Europe & Central Asia"
Croatia["Region"]="Eastern Europe & Central Asia"
Georgia["Region"]="Eastern Europe & Central Asia"
Kazakhstan["Region"]="Eastern Europe & Central Asia"
Kyrgyzstan["Region"]="Eastern Europe & Central Asia"
Montenegro["Region"]="Eastern Europe & Central Asia"
Moldova["Region"]="Eastern Europe & Central Asia"
North_Macedonia["Region"]="Eastern Europe & Central Asia"
Romania["Region"]="Eastern Europe & Central Asia"
Russia["Region"]="Eastern Europe & Central Asia"
Serbia["Region"]="Eastern Europe & Central Asia"
Tajikistan["Region"]="Eastern Europe & Central Asia"
Turkey["Region"]="Eastern Europe & Central Asia"
Turkmenistan["Region"]="Eastern Europe & Central Asia"
Ukraine["Region"]="Eastern Europe & Central Asia"
Uzbekistan["Region"]="Eastern Europe & Central Asia"
Angola["Region"]="Eastern & Southern Africa"
Botswana["Region"]="Eastern & Southern Africa"
Burundi["Region"]="Eastern & Southern Africa"
Comoros["Region"]="Eastern & Southern Africa"
Djibouti["Region"]="Eastern & Southern Africa"
Eritrea["Region"]="Eastern & Southern Africa"
Eswatini["Region"]="Eastern & Southern Africa"
Ethiopia["Region"]="Eastern & Southern Africa"
Kenya["Region"]="Eastern & Southern Africa"
Lesotho["Region"]="Eastern & Southern Africa"
Madagascar["Region"]="Eastern & Southern Africa"
Malawi["Region"]="Eastern & Southern Africa"
Mauritius["Region"]="Eastern & Southern Africa"
Mozambique["Region"]="Eastern & Southern Africa"
Namibia["Region"]="Eastern & Southern Africa"
Rwanda["Region"]="Eastern & Southern Africa"
Seychelles["Region"]="Eastern & Southern Africa"
Somalia["Region"]="Eastern & Southern Africa"
South_Africa["Region"]="Eastern & Southern Africa"
South_Sudan["Region"]="Eastern & Southern Africa"
Sudan["Region"]="Eastern & Southern Africa"
Uganda["Region"]="Eastern & Southern Africa"
Tanzania["Region"]="Eastern & Southern Africa"
Zambia["Region"]="Eastern & Southern Africa"
Zimbabwe["Region"]="Eastern & Southern Africa"
Algeria["Region"]="Middle East & North Africa"
Bahrain["Region"]="Middle East & North Africa"
Egypt["Region"]="Middle East & North Africa"
Iran["Region"]="Middle East & North Africa"
Iraq["Region"]="Middle East & North Africa"
Israel["Region"]="Middle East & North Africa"
Jordan["Region"]="Middle East & North Africa"
Kuwait["Region"]="Middle East & North Africa"
Lebanon["Region"]="Middle East & North Africa"
Libya["Region"]="Middle East & North Africa"
Morocco["Region"]="Middle East & North Africa"
Oman["Region"]="Middle East & North Africa"
Qatar["Region"]="Middle East & North Africa"
Saudi_Arabia["Region"]="Middle East & North Africa"
Palestine["Region"]="Middle East & North Africa"
Syria["Region"]="Middle East & North Africa"
Tunisia["Region"]="Middle East & North Africa"
United_Arab_Emirates["Region"]="Middle East & North Africa"
Yemen["Region"]="Middle East & North Africa"
Canada["Region"]="North America"
United_States["Region"]="North America"
Benin["Region"]="West & Central Africa"
Burkina_Faso["Region"]="West & Central Africa"
Cabo_Verde["Region"]="West & Central Africa"
Cameroon["Region"]="West & Central Africa"
Central_African_Republic["Region"]="West & Central Africa"
Chad["Region"]="West & Central Africa"
DPCongo["Region"]="West & Central Africa"
Cote_dIvoire["Region"]="West & Central Africa"
Congo["Region"]="West & Central Africa"
Equatorial_Guinea["Region"]="West & Central Africa"
Gabon["Region"]="West & Central Africa"
Gambia["Region"]="West & Central Africa"
Ghana["Region"]="West & Central Africa"
Guinea["Region"]="West & Central Africa"
Guinea_Bissau["Region"]="West & Central Africa"
Liberia["Region"]="West & Central Africa"
Mali["Region"]="West & Central Africa"
Mauritania["Region"]="West & Central Africa"
Niger["Region"]="West & Central Africa"
Nigeria["Region"]="West & Central Africa"
Sao_Tome_Principe["Region"]="West & Central Africa"
Senegal["Region"]="West & Central Africa"
Sierra_Leone["Region"]="West & Central Africa"
Togo["Region"]="West & Central Africa"
Afghanistan["Region"]="South Asia"
Bangladesh["Region"]="South Asia"
Bhutan["Region"]="South Asia"
India["Region"]="South Asia"
Maldives["Region"]="South Asia"
Nepal["Region"]="South Asia"
Pakistan["Region"]="South Asia"
Sri_Lanka["Region"]="South Asia"
Andorra["Region"]="Western Europe"
Austria["Region"]="Western Europe"
Belgium["Region"]="Western Europe"
Cyprus["Region"]="Western Europe"
Czechia["Region"]="Western Europe"
Denmark["Region"]="Western Europe"
Estonia["Region"]="Western Europe"
Finland["Region"]="Western Europe"
France["Region"]="Western Europe"
Germany["Region"]="Western Europe"
Greece["Region"]="Western Europe"
Hungary["Region"]="Western Europe"
Iceland["Region"]="Western Europe"
Italy["Region"]="Western Europe"
Latvia["Region"]="Western Europe"
Lithuania["Region"]="Western Europe"
Luxembourg["Region"]="Western Europe"
Malta["Region"]="Western Europe"
Monaco["Region"]="Western Europe"
Netherlands["Region"]="Western Europe"
Norway["Region"]="Western Europe"
Poland["Region"]="Western Europe"
Portugal["Region"]="Western Europe"
San_Marino["Region"]="Western Europe"
Slovenia["Region"]="Western Europe"
Spain["Region"]="Western Europe"
Sweden["Region"]="Western Europe"
Switzerland["Region"]="Western Europe"
United_Kingdom["Region"]="Western Europe"
Antigua_Barbuda["Region"]="Latin America & Caribbean"
Argentina["Region"]="Latin America & Caribbean"
Bahamas["Region"]="Latin America & Caribbean"
Barbados["Region"]="Latin America & Caribbean"
Belize["Region"]="Latin America & Caribbean"
Bolivia["Region"]="Latin America & Caribbean"
Brazil["Region"]="Latin America & Caribbean"
Chile["Region"]="Latin America & Caribbean"
Colombia["Region"]="Latin America & Caribbean"
Costa_Rica["Region"]="Latin America & Caribbean"
Cuba["Region"]="Latin America & Caribbean"
Dominica["Region"]="Latin America & Caribbean"
Dominican_Republic["Region"]="Latin America & Caribbean"
Ecuador["Region"]="Latin America & Caribbean"
El_Salvador["Region"]="Latin America & Caribbean"
Grenada["Region"]="Latin America & Caribbean"
Guatemala["Region"]="Latin America & Caribbean"
Guyana["Region"]="Latin America & Caribbean"
Haiti["Region"]="Latin America & Caribbean"
Honduras["Region"]="Latin America & Caribbean"
Jamaica["Region"]="Latin America & Caribbean"
Mexico["Region"]="Latin America & Caribbean"
Nicaragua["Region"]="Latin America & Caribbean"
Panama["Region"]="Latin America & Caribbean"
Paraguay["Region"]="Latin America & Caribbean"
Peru["Region"]="Latin America & Caribbean"
Saint_Kitts_Nevis["Region"]="Latin America & Caribbean"
Saint_Lucia["Region"]="Latin America & Caribbean"
Saint_Vincent_Grenadines["Region"]="Latin America & Caribbean"
Suriname["Region"]="Latin America & Caribbean"
Trinidad_Tobago["Region"]="Latin America & Caribbean"
Uruguay["Region"]="Latin America & Caribbean"
Venezuela["Region"]="Latin America & Caribbean"
# Out:
# C:\Users\josep\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\josep\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\josep\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
alll = pd.concat([Australia, Brunei_Darussalam, Cambodia, China, Cook_Islands, North_Korea,Fiji,Indonesia,Japan,
                  Kiribati,Lao_PeoplesDP,Malaysia,Marshall_Islands,Micronesia,Mongolia,Myanmar,New_Zealand,Nauru,Niue,
                  Papua_New_Guinea,Palau,Philippines,South_Korea,Samoa,Singapore,Solomon_Islands,Thailand,Timor_Leste,
                  Tonga,Tuvalu,Vanuatu,Viet_Nam,Albania,Armenia,Azerbaijan,Belarus,Bosnia_Herzegovina,Bulgaria,Croatia,
                  Georgia,Kazakhstan,Kyrgyzstan,Montenegro,Moldova,North_Macedonia,Romania,Russia,Serbia,Tajikistan,Turkey,
                  Turkmenistan,Ukraine,Uzbekistan,Angola,Botswana,Burundi,Comoros,Djibouti,Eritrea,Eswatini,Ethiopia,Kenya,
                  Lesotho,Madagascar,Malawi,Mauritius,Mozambique,Namibia,Rwanda,Seychelles,Somalia,South_Africa,South_Sudan,
                  Sudan,Uganda,Tanzania,Zambia,Zimbabwe,Algeria,Bahrain,Egypt,Iran,Iraq,Israel,Jordan,Kuwait,Lebanon,
                  Libya,Morocco,Oman,Qatar,Saudi_Arabia,Palestine,Syria,Tunisia,United_Arab_Emirates,Yemen,Canada,
                  United_States,Benin,Burkina_Faso,Cabo_Verde,Cameroon,Central_African_Republic,Chad,DPCongo,Cote_dIvoire,
                  Congo,Equatorial_Guinea,Gabon,Gambia,Ghana,Guinea,Guinea_Bissau,Liberia,Mali,Mauritania,Niger,Nigeria,
                  Sao_Tome_Principe,Senegal,Sierra_Leone,Togo,Afghanistan,Bangladesh,Bhutan,India,Maldives,Nepal,Pakistan,
                  Sri_Lanka,Andorra,Austria,Belgium,Cyprus,Czechia,Denmark,Estonia,Finland,France,Germany,Greece,Hungary,
                  Iceland,Italy,Latvia,Lithuania,Luxembourg,Malta,Monaco,Netherlands,Norway,Poland,Portugal,San_Marino,
                  Slovenia,Spain,Sweden,Switzerland,United_Kingdom,Antigua_Barbuda,Argentina,Bahamas,Barbados,Belize,
                  Bolivia,Brazil,Chile,Colombia,Costa_Rica,Cuba,Dominica,Dominican_Republic,Ecuador,El_Salvador,Grenada,
                  Guatemala,Guyana,Haiti,Honduras,Jamaica,Mexico,Nicaragua,Panama,Paraguay,Peru,Saint_Kitts_Nevis,
                  Saint_Lucia,Saint_Vincent_Grenadines,Suriname,Trinidad_Tobago,Uruguay,Venezuela])

# %%
reset_index=alll.reset_index()
allData=reset_index.drop(columns=[ "Group", "Subgroup", "Source"])

# %%
allData
allData_filtered = allData[allData['Year'] >= 1996]

# %%
allData_filtered["Target"]= allData_filtered["Target"].str.replace(",","")
allData_filtered["Vaccinated"]= allData_filtered["Vaccinated"].str.replace(",","")
allData_filtered["Target"].astype(str)
allData_filtered["Vaccinated"].astype(str)
allData_filtered.Target = pd.to_numeric(allData_filtered.Target, errors='coerce')
allData_filtered.Vaccinated = pd.to_numeric(allData_filtered.Vaccinated, errors='coerce')
allData_filtered.dtypes
# Out:
# Name           object
# Year            int64
# Vaccine        object
# Coverage        int64
# Vaccinated    float64
# Target        float64
# Region         object
# dtype: object

# %%
allData_filtered["Vaccinations Needed"] = allData_filtered["Target"] -  allData_filtered["Vaccinated"]
allData_filtered.rename({'Name': 'Country'}, axis=1, inplace=True)
allData_filtered.head()
# Out:
#      Country  Year Vaccine  Coverage  Vaccinated    Target  \
# 0  Australia  2018    DTP1        98    311000.0  317000.0
# 1  Australia  2018    DTP3        95    302000.0  317000.0
# 2  Australia  2018   Hepb3        95    302000.0  317000.0
# 3  Australia  2018    Hib3        94    298000.0  317000.0
# 4  Australia  2018    MCV1        95    302000.0  317000.0
#
#                 Region  Vaccinations Needed
# 0  East Asia & Pacific               6000.0
# 1  East Asia & Pacific              15000.0
# 2  East Asia & Pacific              15000.0
# 3  East Asia & Pacific              19000.0
# 4  East Asia & Pacific              15000.0

# %%
allData_filtered = allData_filtered[['Year', 'Country', 'Region', 'Vaccine', 'Target', 
                                     'Vaccinated', 'Vaccinations Needed', 'Coverage']].dropna()

# %%
allData_filteredR=allData_filtered.set_index(["Region"]).dropna()
allData_filteredR.head()
# Out:
#                      Year    Country Vaccine    Target  Vaccinated  \
# Region
# East Asia & Pacific  2018  Australia    DTP1  317000.0    311000.0
# East Asia & Pacific  2018  Australia    DTP3  317000.0    302000.0
# East Asia & Pacific  2018  Australia   Hepb3  317000.0    302000.0
# East Asia & Pacific  2018  Australia    Hib3  317000.0    298000.0
# East Asia & Pacific  2018  Australia    MCV1  317000.0    302000.0
#
#                      Vaccinations Needed  Coverage
# Region
# East Asia & Pacific               6000.0        98
# East Asia & Pacific              15000.0        95
# East Asia & Pacific              15000.0        95
# East Asia & Pacific              19000.0        94
# East Asia & Pacific              15000.0        95

# %%
allData_filteredR.to_csv(r'CSVs\AllData.csv')
allData_filtered.to_csv(r'CSVs\AllData_NoIndex.csv')

# %%
allData_filtered.drop(columns=['Region'])
# Out:
#        Year                             Country Vaccine    Target  Vaccinated  \
# 0      2018                           Australia    DTP1  317000.0    311000.0
# 1      2018                           Australia    DTP3  317000.0    302000.0
# 2      2018                           Australia   Hepb3  317000.0    302000.0
# 3      2018                           Australia    Hib3  317000.0    298000.0
# 4      2018                           Australia    MCV1  317000.0    302000.0
# 5      2018                           Australia    MCV2  329000.0    306000.0
# 6      2018                           Australia    PCV3  317000.0    302000.0
# 7      2018                           Australia    Pol3  317000.0    302000.0
# 8      2018                           Australia    RCV1  317000.0    302000.0
# 9      2018                           Australia   Rotac  317000.0    276000.0
# 10     2017                           Australia    DTP1  317000.0    310000.0
# ...

# %%
DTP1=allData_filtered[allData_filtered["Vaccine"]=="DTP1"].drop(columns=["Vaccine", "Region"])
DTP3=allData_filtered[allData_filtered["Vaccine"]=="DTP3"].drop(columns=["Vaccine", "Region"])
Hepb3=allData_filtered[allData_filtered["Vaccine"]=="Hepb3"].drop(columns=["Vaccine", "Region"])
Hib3=allData_filtered[allData_filtered["Vaccine"]=="Hib3"].drop(columns=["Vaccine", "Region"])
MCV1=allData_filtered[allData_filtered["Vaccine"]=="MCV1"].drop(columns=["Vaccine", "Region"])
MCV2=allData_filtered[allData_filtered["Vaccine"]=="MCV2"].drop(columns=["Vaccine", "Region"])
PCV3=allData_filtered[allData_filtered["Vaccine"]=="PCV3"].drop(columns=["Vaccine", "Region"])
Pol3=allData_filtered[allData_filtered["Vaccine"]=="Pol3"].drop(columns=["Vaccine", "Region"])
RCV1=allData_filtered[allData_filtered["Vaccine"]=="RCV1"].drop(columns=["Vaccine", "Region"])
Rotac=allData_filtered[allData_filtered["Vaccine"]=="Rotac"].drop(columns=["Vaccine", "Region"])
BCG=allData_filtered[allData_filtered["Vaccine"]=="BCG"].drop(columns=["Vaccine", "Region"])
Hepbb=allData_filtered[allData_filtered["Vaccine"]=="Hepbb"].drop(columns=["Vaccine", "Region"])
IPV1=allData_filtered[allData_filtered["Vaccine"]=="IPV1"].drop(columns=["Vaccine", "Region"])
YFV=allData_filtered[allData_filtered["Vaccine"]=="YFV"].drop(columns=["Vaccine", "Region"])

# %%
DTP1= DTP1.reset_index()

# %%
DTP1=DTP1.dropna()
DTP1.head()
# Out:
#    index  Year    Country    Target  Vaccinated  Vaccinations Needed  Coverage
# 0      0  2018  Australia  317000.0    311000.0               6000.0        98
# 1     10  2017  Australia  317000.0    310000.0               7000.0        98
# 2     20  2016  Australia  315000.0    309000.0               6000.0        98
# 3     30  2015  Australia  314000.0    304000.0              10000.0        97
# 4     40  2014  Australia  312000.0    287000.0              25000.0        92
